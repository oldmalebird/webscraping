# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# %%
def main():
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36',
    'Host': 'hangqing.ymt.com',
    'Connection': 'keep-alive',
    'Referer': 'http://hangqing.ymt.com/chandi/',
    'Cookie':'sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22%24device_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fwww.baidu.com%2Flink%22%2C%22%24latest_referrer_host%22%3A%22www.baidu.com%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%7D%7D; __cfduid=d7d38f2b04f4b2fa36d82a201664cb3fb1560913285; __permanent_id=20190619110128725755084922834522248; Hm_lvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; Hm_lpvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; __click_visit=0000000001.4; out_refer=www.baidu.com%7C; Hm_lvt_910abd56d68f662e980cbb010333d8f5=1560913289,1561014253; Hm_lpvt_910abd56d68f662e980cbb010333d8f5=1561014628; hangqing_session=%3D; __trace_id=20190620151034579173363218287366151'
    }
    url = 'http://hangqing.ymt.com/chandi/'
    result = requests.get(url, headers = headers)
    print(result.text)

if __name__ == '__main__':
    main()
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 6 ]> <html class="ie ie6 lte_ie7" lang="zh-CN"> <![endif]-->
# <!--[if IE 7 ]> <html class="ie ie7 lte_ie7" lang="zh-CN"> <![endif]-->
# <!--[if IE 8 ]> <html class="ie ie8" lang="zh-CN"> <![endif]-->
# <!--[if IE 9 ]> <html class="ie ie9" lang="zh-CN"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
#   <html lang="zh-CN">
#   <!--<![endif]-->
#   <head>
#     <meta http-equiv="content-type" content="text/html;charset=utf-8" />
#     <meta name="renderer" content="webkit">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
#     <title>今日农产品产地批发价格行情-一亩田农业网</title>
#     <meta name="Keywords" content="农产品价格行情,农产品产地行情,农产品批发市场行情"/>
#     <meta name="Description" content="一亩田行情分析频道提供农产品最新价格、农产品价格走势、农产品产地/批发市场价格行情分析预测及今日农产品时时价格行情数据，包括:家畜、蔬菜、水果、绿化苗木、粮油、水产、家禽、特种养殖、药材、经济作物价格信息。查看农产品行情分析、价格行情信息就上一亩田农业网行情分析频道。"/>
#             <meta http-equiv="mobile-agent" content="format=html5; url=http://m.hangqing.ymt.com/chandi">
# ...

# %%
def main():
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36',
    'Host': 'hangqing.ymt.com',
    'Connection': 'keep-alive',
    'Referer': 'http://hangqing.ymt.com/chandi/',
    'Cookie':'sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22%24device_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fwww.baidu.com%2Flink%22%2C%22%24latest_referrer_host%22%3A%22www.baidu.com%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%7D%7D; __cfduid=d7d38f2b04f4b2fa36d82a201664cb3fb1560913285; __permanent_id=20190619110128725755084922834522248; Hm_lvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; Hm_lpvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; __click_visit=0000000001.4; out_refer=www.baidu.com%7C; Hm_lvt_910abd56d68f662e980cbb010333d8f5=1560913289,1561014253; Hm_lpvt_910abd56d68f662e980cbb010333d8f5=1561014628; hangqing_session=%3D; __trace_id=20190620151034579173363218287366151'
    }
    url = 'http://hangqing.ymt.com/chandi/'
    result = requests.get(url, headers = headers)
    print(result.text)

if __name__ == '__main__':
    main()
Referrer Policy

# %%
def main():
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36',
    'Host': 'hangqing.ymt.com',
    'Connection': 'keep-alive',
    'Referer': 'http://hangqing.ymt.com/chandi/',
    'Cookie':'sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22%24device_id%22%3A%2216b6dabadc27c2-08ec1087209462-e353165-2764800-16b6dabadc3474%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E8%87%AA%E7%84%B6%E6%90%9C%E7%B4%A2%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22https%3A%2F%2Fwww.baidu.com%2Flink%22%2C%22%24latest_referrer_host%22%3A%22www.baidu.com%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC%22%7D%7D; __cfduid=d7d38f2b04f4b2fa36d82a201664cb3fb1560913285; __permanent_id=20190619110128725755084922834522248; Hm_lvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; Hm_lpvt_fbff43aedd674a772ac04ce3bf61f47e=1560913425; __click_visit=0000000001.4; out_refer=www.baidu.com%7C; Hm_lvt_910abd56d68f662e980cbb010333d8f5=1560913289,1561014253; Hm_lpvt_910abd56d68f662e980cbb010333d8f5=1561014628; hangqing_session=%3D; __trace_id=20190620151034579173363218287366151'
    }
    url = 'http://hangqing.ymt.com/chandi/'
    result = requests.get(url, headers = headers)
    print(result.text)

if __name__ == '__main__':
    main()http://hangqing.ymt.com/chandi_7382_0_0
