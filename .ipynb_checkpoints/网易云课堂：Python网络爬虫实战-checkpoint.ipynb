# %% [markdown]
# ##  网易云课堂：Python网络爬虫实战

# %% [markdown]
# 非结构化数据→结构化数据：例如新闻

# %%
import requests
res = requests.get('http://news.sina.com.cn/china/')
print(res.encoding)
# Out:
# ISO-8859-1

# %%
res.encoding = 'utf-8'
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <title>国内新闻_新闻中心_新浪网</title>
# <meta name="keywords" content="国内时政,内地新闻">
# <meta name="description" content="新闻中心国内频道，纵览国内时政、综述评论及图片的栏目，主要包括时政要闻、内地新闻、港澳台新闻、媒体聚焦、评论分析。">
# <meta name="robots" content="noarchive">
# <meta name="Baiduspider" content="noarchive">
# <meta http-equiv="Cache-Control" content="no-transform">
# <meta http-equiv="Cache-Control" content="no-siteapp">
# <meta name="applicable-device" content="pc,mobile">
# <meta name="MobileOptimized" content="width">
# <meta name="HandheldFriendly" content="true">
# <meta content="always" name="referrer">
#     <link rel="mask-icon" sizes="any" href="//www.sina.com.cn/favicon.svg" color="red">
#     <!-- 登录 css -->
#     <link rel="stylesheet" type="text/css" href="//i.sso.sina.com.cn/css/userpanel/v1/top_account_v2.css">
#     <!-- feed css -->
#     <link rel="stylesheet" href="//n0.sinaimg.cn/news/china/feed.1.1.7.css" type="text/css" />
#     <link rel="stylesheet" href="//news.sina.com.cn/268/2014/0919/bshare_update.css" type="text/css">
#
#     <script src='//n.sinaimg.cn/news/libs/jquery-1.11.1.min.js'></script>
#     <link href="//simg.sinajs.cn/products/news_finance/2018/pc_china_home/css/index-1edb9c.css" rel="stylesheet">
# </head>
#
# <body><!-- body code begin -->
#
# <!-- SUDA_CODE_START -->
# <script type="text/javascript">
# //<!--
# (function(){var an="V=2.1.16";var ah=window,F=document,s=navigator,W=s.userAgent,ao=ah.screen,j=ah.location.href;var aD="https:"==ah.location.protocol?"https://s":"http://",ay="beacon.sina.com.cn";var N=aD+ay+"/a.gif?",z=aD+ay+"/g.gif?",R=aD+ay+"/f.gif?",ag=aD+ay+"/e.gif?",aB=aD+"beacon.sinauda.com/i.gif?";var aA=F.referrer.toLowerCase();var aa="SINAGLOBAL",Y="FSINAGLOBAL",H="Apache",P="ULV",l="SUP",aE="UOR",E="_s_acc",X="_s_tentry",n=false,az=false,B=(document.domain=="sina.com.cn")?true:false;var o=0;var aG=false,A=false;var al="";var m=16777215,Z=0,C,K=0;var r="",b="",a="";var M=[],S=[],I=[];var u=0;var v=0;var p="";var am=false;var w=false;function O(){var e=document.createElement("iframe");e.src=aD+ay+"/data.html?"+new Date().getTime();e.id="sudaDataFrame";e.style.height="0px";e.style.width="1px";e.style.overflow="hidden";e.frameborder="0";e.scrolling="no";document.getElementsByTagName("head")[0].appendChild(e)}function k(){var e=document.createElement("iframe");e.src=aD+ay+"/ckctl.html";e.id="ckctlFrame";e.style.height="0px";e.style.width="1px";e.style.overflow="hidden";e.frameborder="0";e.scrolling="no";document.getElementsByTagName("head")[0].appendChild(e)}function q(){var e=document.createElement("script");e.src=aD+ay+"/h.js";document.getElementsByTagName("head")[0].appendChild(e)}function h(aH,i){var D=F.getElementsByName(aH);var e=(i>0)?i:0;return(D.length>e)?D[e].content:""}function aF(){var aJ=F.getElementsByName("sudameta");var aR=[];for(var aO=0;aO<aJ.length;aO++){var aK=aJ[aO].content;if(aK){if(aK.indexOf(";")!=-1){var D=aK.split(";");for(var aH=0;aH<D.length;aH++){var aP=aw(D[aH]);if(!aP){continue}aR.push(aP)}}else{aR.push(aK)}}}var aM=F.getElementsByTagName("meta");for(var aO=0,aI=aM.length;aO<aI;aO++){var aN=aM[aO];if(aN.name=="tags"){aR.push("content_tags:"+encodeURI(aN.content))}}var aL=t("vjuids");aR.push("vjuids:"+aL);var e="";var aQ=j.indexOf("#");if(aQ!=-1){e=escape(j.substr(aQ+1));aR.push("hashtag:"+e)}return aR}function V(aK,D,aI,aH){if(aK==""){return""}aH=(aH=="")?"=":aH;D+=aH;var aJ=aK.indexOf(D);if(aJ<0){return""}aJ+=D.length;var i=aK.indexOf(aI,aJ);if(i<aJ){i=aK.length}return aK.substring(aJ,i)}function t(e){if(undefined==e||""==e){return""}return V(F.cookie,e,";","")}function at(aI,e,i,aH){if(e!=null){if((undefined==aH)||(null==aH)){aH="sina.com.cn"}if((undefined==i)||(null==i)||(""==i)){F.cookie=aI+"="+e+";domain="+aH+";path=/"}else{var D=new Date();var aJ=D.getTime();aJ=aJ+86400000*i;D.setTime(aJ);aJ=D.getTime();F.cookie=aI+"="+e+";domain="+aH+";expires="+D.toUTCString()+";path=/"}}}function f(D){try{var i=document.getElementById("sudaDataFrame").contentWindow.storage;return i.get(D)}catch(aH){return false}}function ar(D,aH){try{var i=document.getElementById("sudaDataFrame").contentWindow.storage;i.set(D,aH);return true}catch(aI){return false}}function L(){var aJ=15;var D=window.SUDA.etag;if(!B){return"-"}if(u==0){O();q()}if(D&&D!=undefined){w=true}ls_gid=f(aa);if(ls_gid===false||w==false){return false}else{am=true}if(ls_gid&&ls_gid.length>aJ){at(aa,ls_gid,3650);n=true;return ls_gid}else{if(D&&D.length>aJ){at(aa,D,3650);az=true}var i=0,aI=500;var aH=setInterval((function(){var e=t(aa);if(w){e=D}i+=1;if(i>3){clearInterval(aH)}if(e.length>aJ){clearInterval(aH);ar(aa,e)}}),aI);return w?D:t(aa)}}function U(e,aH,D){var i=e;if(i==null){return false}aH=aH||"click";if((typeof D).toLowerCase()!="function"){return}if(i.attachEvent){i.attachEvent("on"+aH,D)}else{if(i.addEventListener){i.addEventListener(aH,D,false)}else{i["on"+aH]=D}}return true}function af(){if(window.event!=null){return window.event}else{if(window.event){return window.event}var D=arguments.callee.caller;var i;var aH=0;while(D!=null&&aH<40){i=D.arguments[0];if(i&&(i.constructor==Event||i.constructor==MouseEvent||i.constructor==KeyboardEvent)){return i}aH++;D=D.caller}return i}}function g(i){i=i||af();if(!i.target){i.target=i.srcElement;i.pageX=i.x;i.pageY=i.y}if(typeof i.layerX=="undefined"){i.layerX=i.offsetX}if(typeof i.layerY=="unde ...
# //-->
# </script>
# <noScript>
# <div style='position:absolute;top:0;left:0;width:0;height:0;visibility:hidden'><img width=0 height=0 src='//beacon.sina.com.cn/a.gif?noScript' border='0' alt='' /></div>
# </noScript>
# <!-- SUDA_CODE_END -->
#
# <!-- SSO_GETCOOKIE_START -->
# <script type="text/javascript">var sinaSSOManager=sinaSSOManager||{};sinaSSOManager.getSinaCookie=function(){function dc(u){if(u==undefined){return""}var decoded=decodeURIComponent(u);return decoded=="null"?"":decoded}function ps(str){var arr=str.split("&");var arrtmp;var arrResult={};for(var i=0;i<arr.length;i++){arrtmp=arr[i].split("=");arrResult[arrtmp[0]]=dc(arrtmp[1])}return arrResult}function gC(name){var Res=eval("/"+name+"=([^;]+)/").exec(document.cookie);return Res==null?null:Res[1]}var sup=dc(gC("SUP"));if(!sup){sup=dc(gC("SUR"))}if(!sup){return null}return ps(sup)};</script>
# <!-- SSO_GETCOOKIE_END -->
#
# <script type="text/javascript">new function(r,s,t){this.a=function(n,t,e){if(window.addEventListener){n.addEventListener(t,e,false);}else if(window.attachEvent){n.attachEvent("on"+t,e);}};this.b=function(f){var t=this;return function(){return f.apply(t,arguments);};};this.c=function(){var f=document.getElementsByTagName("form");for(var i=0;i<f.length;i++){var o=f[i].action;if(this.r.test(o)){f[i].action=o.replace(this.r,this.s);}}};this.r=r;this.s=s;this.d=setInterval(this.b(this.c),t);this.a(window,"load",this.b(function(){this.c();clearInterval(this.d);}));}(/http:\/\/www\.google\.c(om|n)\/search/, "http://keyword.sina.com.cn/searchword.php", 250);</script>
# <!-- body code end -->
#
#
#     <!--主导航-->
# <div class="sina-header" id="sina-header">
#     <div class="sina-header-inner">
#         <div class="sina-nav">
#             <ul class="nav-list">
#                 <li class="first" data-sudaclick="nav_home_p"><a href="http://www.sina.com.cn/">新浪首页</a></li>
#                 <li data-sudaclick="nav_news_p"><a href="http://news.sina.com.cn/">新闻</a></li>
#                 <li data-sudaclick="nav_sports_p"><a href="http://sports.sina.com.cn/">体育</a></li>
#                 <li data-sudaclick="nav_finance_p"><a href="http://finance.sina.com.cn/">财经</a></li>
#                 <li data-sudaclick="nav_ent_p"><a href="http://ent.sina.com.cn/">娱乐</a></li>
#                 <li data-sudaclick="nav_tech_p"><a href="http://tech.sina.com.cn/">科技</a></li>
#                 <li data-sudaclick="nav_blog_p"><a href="http://blog.sina.com.cn/">博客</a></li>
#                 <li data-sudaclick="nav_photo_p"><a href="http://photo.sina.com.cn/">图片</a></li>
#                 <li data-sudaclick="nav_zhuanlan_p"><a href="http://zhuanlan.sina.com.cn/">专栏</a></li>
#                 <li class="last" data-sudaclick="topnav_more_p"><a href="#" class="more" data-action="dropdown" data-target="more">更多<i class="icon icon-arrow"></i></a></li>
#                 <!--鼠标滑过更多<a>标签添加class="sina15-on"-->
#             </ul>
#             <ul id="more" class="nav-others">
#                 <li><a data-sudaclick="nav_auto_p" href="http://auto.sina.com.cn/">汽车</a><a data-sudaclick="nav_edu_p" href="http://edu.sina.com.cn/">教育</a><a data-sudaclick="nav_fashion_p" href="http://fashion.sina.com.cn/">时尚</a><a data-sudaclick="nav_eladies_p" href="http://eladies.sina.com.cn/">女性</a><a data-sudaclick="nav_astro_p" href="http://astro.sina.com.cn/">星座</a><a data-sudaclick="nav_health_p" href="http://health.sina.com.cn/">健康</a></li>
#                 <li><a data-sudaclick="nav_leju_p" href="http://www.leju.com/#source=pc_sina_dbdh1&source_ext=pc_sina">房产</a><a data-sudaclick="nav_history_p"  href="http://history.sina.com.cn/">历史</a><a data-sudaclick="nav_video_p" href="http://video.sina.com.cn/">视频</a><a data-sudaclick="nav_collection_p" href="http://collection.sina.com.cn/">收藏</a><a data-sudaclick="nav_baby_p" href="http://baby.sina.com.cn/">育儿</a><a data-sudaclick="nav_book_p" href="http://book.sina.com.cn/">读书</a></li>
#                 <li class="nav-others-last"><a data-sudaclick="nav_fo_p" href="http://fo.sina.com.cn/">佛学</a><a data-sudaclick="nav_games_p" href="http://games.sina.com.cn/">游戏</a><a data-sudaclick="nav_travel_p" href="http://travel.sina.com.cn/">旅游</a><a data-sudaclick="nav_mail_p" href="http://mail.sina.com.cn/">邮箱</a><a data-sudaclick="nav_guide_p" href="http://news.sina.com.cn/guide/">导航</a></li>
#             </ul>
#         </div>
#         <!--通行证组件start-->
#         <div class="sina-client">
#             <div class="sina-client-tl">
#                 <a class="more" href="#" data-action="dropdown" data-target="mobileclient">移动客户端<i class="icon icon-arrow"></i></a>
#             </div>
#             <ul id="mobileclient" class="dropdown">
#                 <li><a data-sudaclick="nav_app_weibo_p" href="http://m.sina.com.cn/m/weibo.shtml" target="_blank"><i class="ico-client ico-weibo"></i>新浪微博</a></li>
#                 <li><a data-sudaclick="nav_app_news_p" href="http://news.sina.com.cn/m/sinanews.html" target="_blank"><i class="ico-client ico-news"></i>新浪新闻</a></li>
#                 <li><a data-sudaclick="nav_app_sports_p" href="http://m.sina.com.cn/m/sinasports.shtml" target="_blank"><i class="ico-client ico-sports"></i>新浪体育</a></li>
#                 <li><a data-sudaclick="nav_app_ent_p" href="http://ent.sina.com.cn/app/download/" target="_blank"><i class="ico-client ico-ent"></i>新浪娱乐</a></li>
#                 <li><a data-sudaclick="nav_app_finance_p" href="http://finance.sina.com.cn/mobile/comfinanceweb.shtml" target="_blank"><i class="ico-client ico-finance"></i>新浪财经</a></li>
#                 <li><a href="http://zhongce.sina.com.cn/about/app" target="_blank" data-sudaclick="nav_app_zhongce_p"><i class="ico-client ico-zhongce"></i>新浪众测</a></li>
#                 <li><a data-sudaclick="nav_app_blog_p" href="http://blog.sina.com.cn/lm/z/app/" target="_blank"><i class="ico-client ico-blog"></i>新浪博客</a></li>
#                 <li><a data-sudaclick="nav_app_video_p" href="http://video.sina.com.cn/app" target="_blank"><i class="ico-client ico-video"></i>新浪视频</a></li>
#                 <li><a data-sudaclick="nav_app_game_p" href="http://games.sina.com.cn/o/kb/12392.shtml" target="_blank"><i class="ico-client ico-games"></i>新浪游戏</a></li>
#                 <li><a data-sudaclick="nav_app_weather_p" href="http://m.sina.com.cn/m/weather.shtml" target="_blank"><i class="ico-client ico-weather"></i>天气通</a></li>
#             </ul>
#         </div>
#         <!-- 我的收藏start -->
#         <div class="my-favor" id="my_favor" style="display:none;">
#             <a data-sudaclick="nav_myfav_p" href="http://my.sina.com.cn/#location=fav" target="_blank"><i></i>我的收藏</a>
#         </div>
#
#         <!-- 我的收藏end -->
#         <div id="SI_User" class="TAP14">
#             <div class="ac-rgst"><a data-sudaclick="nav_registered_invalid" href="https://login.sina.com.cn/signup/signup?entry=news" class="msg-link" target="_blank">注册</a></div>
#             <div class="ac-login">
#                 <div class="ac-login-cnt "><a data-sudaclick="nav_login_invalid" href="#" class=""><span class="thumb"><img src="//i.sso.sina.com.cn/images/login/thumb_default.png"></span><span class="log-links">登录</span></a></div>
#             </div>
#         </div>
#
#     </div>
# </div>
# <!--/主导航-->
# <!--页面顶导 end-->
#     <div class="main-content">
#         <div class="top-ad" data-sudaclick="ad_top_p">
#     <!--顶部通栏 Start-->
#     <script>
#         (function (d, s, id) {
#             var s, n = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) return;
#             s = d.createElement(s);
#             s.id = id;
#             s.setAttribute('charset', 'utf-8');
#             s.src = '//d' + Math.floor(0 + Math.random() * (9 - 0 + 1)) + '.sina.com.cn/litong/zhitou/sinaads/release/sinaads.js';
#             n.parentNode.insertBefore(s, n);
#         })(document, 'script', 'sinaads-script');
#     </script>
#     <ins class="sinaads" data-ad-pdps="PDPS000000058096"></ins>
#     <script>(sinaads = window.sinaads || []).push({})</script>
#     <!--顶部通栏 End-->
# </div>
#         <!--
#  * Module: 面包削
#  * Author: jinping3
#  * Date: 2018.03.29
# -->
# <div class="path-search">
#     <div class="path">
#         <div class="channel-logo"><a data-sudaclick="cnav_logo_news_p" href="http://news.sina.com.cn/"><span>新闻中心</span></a></div>
#     </div>
#     <div class="search ent-search" id='ent_search' data-sudaclick="cnav_search_p">
#         <form action="//search.sina.com.cn/" name="cheadSearchForm" id="all_search" method="get"
#               target="_blank" style="position: relative;">
#             <select name="c" id="search_type" style="visibility: hidden;">
#                 <option value="news">新闻</option>
#                 <option value="img">图片</option>
#                 <option value="blog">博客</option>
#                 <option value="video">视频</option>
#             </select>
#             <input type="hidden" name="ie" value="utf-8">
#             <div class="search_div">
#                 <input type="text" id="search_input" name="q" value="请输入关键词" onfocus="if(this.value == '请输入关键词') this.value = ''" onblur="if(this.value =='') this.value = '请输入关键词'" autocomplete="off">
#                 <div class="search_btn_box"><input type="submit" id="search_submit" value=""></div>
#             </div>
#         </form>
#     </div>
# </div>
# <!-- 面包削 search end -->
#     </div>
#     <div class="main-nav" data-sudaclick="top_channle_nav_p">
#     <ul class="main-text">
#         <li><a href="http://news.sina.com.cn">首页</a></li>
#         <li><a href="http://news.sina.com.cn/china/" target="_blank"  class="current">国内</a></li>
#         <li><a href="http://news.sina.com.cn/world/" target="_blank">国际</a></li>
#         <li><a href="http://news.sina.com.cn/society/" target="_blank">社会</a></li>
#         <li><a href="http://mil.news.sina.com.cn/" target="_blank">军事</a></li>
#         <li><a href="http://news.video.sina.com.cn/" target="_blank">视频</a></li>
#         <li><a href="http://cul.news.sina.com.cn/" target="_blank">文化</a></li>
#         <li><a href="http://news.sina.com.cn/vr/" target="_blank">VR视频</a></li>
#         <li><a href="http://news.sina.com.cn/opinion/" target="_blank">评论</a></li>
#         <li class="none"><a href="http://photo.sina.com.cn/" target="_blank">图片</a></li>
#         <!-- <li class="none"><a href="http://games.sina.com.cn/" target="_blank">游戏</a></li> -->
#     </ul>
# </div>
#     <div class="main-content">
#         <div class="left-content">
#             <div class="picBox" id="picBox"  data-sudaclick="focuspic_p">
#     <ul class="img">
#         					<li>
#             <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323865.html" target="_blank" title="杨洁篪在北京会见蓬佩奥  敦促美方停止损害中方利益的行动">
#                 <span class="img-span"><img src="//k.sinaimg.cn/n/news/transform/200/w600h400/20181009/s5Ro-hktxqai1811675.jpg/w500h333l80572.jpg" width="500" height="333" alt="杨洁篪在北京会见蓬佩奥  敦促美方停止损害中方利益的行动" class="img-hover" /></span>
#                 <span class="title">杨洁篪在北京会见蓬佩奥  敦促美方停止损害中方利...</span>
#             </a>
#         </li>										<li>
#             <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323864.html" target="_blank" title="1000平米泡沫厂房起火 无人员伤亡">
#                 <span class="img-span"><img src="//k.sinaimg.cn/n/news/transform/200/w600h400/20181009/71-f-hkvrhpt2072167.jpg/w500h333l80695.jpg" width="500" height="333" alt="1000平米泡沫厂房起火 无人员伤亡" class="img-hover" /></span>
#                 <span class="title">1000平米泡沫厂房起火 无人员伤亡</span>
#             </a>
#         </li>										<li>
#             <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323685.html" target="_blank" title="秋风起，叶先知">
#                 <span class="img-span"><img src="//k.sinaimg.cn/n/news/1_img/upload/72f96829/283/w650h433/20181007/kReJ-hktxqah9739025.jpg/w500h333l80df2.jpg" width="500" height="333" alt="秋风起，叶先知" class="img-hover" /></span>
#                 <span class="title">秋风起，叶先知</span>
#             </a>
#         </li>
#     </ul>
#     <ul>
#        <li>
#             <a class="btn btn_l" href="javascript:;"></a>
#         </li>
#         <li >
#             <a class="btn btn_r" href="javascript:;"></a>
#         </li>
#     </ul>
#     <div class="titsBox">
#         <ul class="num"></ul>
#     </div>
# </div>
#             <div class="video-box" data-sudaclick="videolist_p">
#     <ul>
#         			<li>
#             <a href="http://video.sina.com.cn/p/news/c/doc/2018-10-09/072569038328.html" target="_blank">
#                 <span class="img-span">
#                     <img src="//p.ivideo.sina.com.cn/video/265/715/073/265715073.jpg" width="240" height="160" alt="书店实行门票收费制 你愿意花钱去看书吗？" class="img-hover" />
#                     <i class="icon-video"></i>
#                 </span>
#                 <span class="text-span">书店实行门票收费制 你愿意花钱去看书吗？</span>
#             </a>
#         </li>
# 			<li>
#             <a href="http://video.sina.com.cn/p/news/c/doc/2018-10-08/214569038177.html" target="_blank">
#                 <span class="img-span">
#                     <img src="//p.ivideo.sina.com.cn/video/265/715/073/265715073.jpg" width="240" height="160" alt="书店实行门票收费制  你愿意花钱去看书吗" class="img-hover" />
#                     <i class="icon-video"></i>
#                 </span>
#                 <span class="text-span">书店实行门票收费制  你愿意花钱去看书吗</span>
#             </a>
#         </li>
# 			<li>
#             <a href="http://video.sina.com.cn/p/news/c/doc/2018-10-08/205969038117.html" target="_blank">
#                 <span class="img-span">
#                     <img src="//p.ivideo.sina.com.cn/video/265/713/117/265713117.jpg" width="240" height="160" alt="精准施策看“六稳” 中国有能力实现全年主要经济目标" class="img-hover" />
#                     <i class="icon-video"></i>
#                 </span>
#                 <span class="text-span">精准施策看“六稳” 中国有能力实现全年主要经济目标</span>
#             </a>
#         </li>
# 			<li>
#             <a href="http://video.sina.com.cn/p/news/c/doc/2018-10-08/121569037555.html" target="_blank">
#                 <span class="img-span">
#                     <img src="//p.ivideo.sina.com.cn/video/265/655/407/265655407.jpg" width="240" height="160" alt="只因隔着车窗多看了一眼 交警抓获一名逃犯" class="img-hover" />
#                     <i class="icon-video"></i>
#                 </span>
#                 <span class="text-span">只因隔着车窗多看了一眼 交警抓获一名逃犯</span>
#             </a>
#         </li>
#
#     </ul>
# </div>
#         </div>
#         <div class="right-content">
#             <ul class="news-1"  data-sudaclick="news_p">
#
# 		<li><a href="https://news.sina.com.cn/o/2018-10-08/doc-ifxeuwws2159806.shtml" target="_blank">文在寅称习近平不久后将访问朝鲜？外交部回应</a></li>		<li><a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws2155730.shtml" target="_blank">公安部凌晨召开紧急会议 透露孟宏伟违法关键信息</a></li>		<li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2048862.shtml" target="_blank">中美外交一次短兵相接 这四个细节意味深长</a></li>		<li><a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws2169821.shtml" target="_blank">彭斯“诋毁中国”话音刚落 蓬佩奥就来华做这件事</a></li>
#             </ul>
#             <ul class="news-2"  data-sudaclick="news_p">
#                 <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2133025.shtml" target="_blank">马英九吃喜酒时吐露婚姻秘诀：要让太太完全执政</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2280385.shtml" target="_blank">蓬佩奥访华聚焦朝核但难避中美关系 否认围堵中国</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2279183.shtml" target="_blank">13位省级领导在国庆假期工作 事关中央这项部署</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2271670.shtml" target="_blank">在这两个领域 国务院出台重磅措施</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2053171.shtml" target="_blank">2年内才会和大陆建交？让帕劳“犹豫”的原因是它</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2048862.shtml" target="_blank">中美外交一次短兵相接 这四个细节意味深长</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2266063.shtml" target="_blank">中办国办文件:地方政府储备土地前须完成考古工作</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2023836.shtml" target="_blank">贵州省委常委会：坚决拥护王晓光被双开的决定</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2014575.shtml" target="_blank">新京报：带薪休假落实难 不妨考虑恢复五一黄金周</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2002212.shtml" target="_blank">党报：“美国优先”挡不住新型经济全球化进程</a></li>
# <li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2259754.shtml" target="_blank">大陆游客给台湾警察送锦旗 算不算“统战”行为？</a></li>
#
#             </ul>
#         </div>
#     </div>
#     <div class="main-content">
#         <div class="left-content-1 marBot">
#             <div class="switch-box" data-sudaclick="left_picblock_p">
#     <div class="tlt">
#         <em><a href="http://slide.news.sina.com.cn/c/" target="_blank">图片</a></em>
#     </div>
#     <div class="switch-text">
#         <ul>
#
#
#
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323649.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/transform/200/w600h400/20181007/u_Px-hkrzvkw0386036.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">国庆假期进入尾声 北京八达岭长城游人众多</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323647.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/1_img/vcg/72f96829/126/w1024h702/20181007/Qtdn-hkvrhps8115155.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">666架钢琴共同奏响 成功挑战吉尼斯世界纪录</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_86058_323646.html" target="_blank">
#                     <img src="//n.sinaimg.cn/translate/656/w899h557/20181006/Vzqy-hkvrhps7749973.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">突破8万人次 高铁香港西九龙站口岸5日客流量再创新高</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_86058_323656.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/transform/200/w600h400/20181007/LcNQ-hkrzvkw0415605.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">国庆长假余额不足 多地迎来返程客流高峰</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323361.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/1_img/vcg/c4b46437/107/w1024h683/20181003/gW9m-hktxqah4328601.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">国庆假期第二天 各景区“人山人海”依旧</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323357.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/transform/200/w600h400/20181003/CotU-hkrzvkv5831615.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">四川折多山降暴雪 上千出游车辆被困</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323273.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/1_img/upload/8de453bf/606/w900h506/20181002/53l1-hktxqah3241972.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">国产水陆两栖飞机完成首次水上高速滑行</span>
#                 </a>
#             </li>
# 							 <li>
#                 <a href="http://slide.news.sina.com.cn/c/slide_1_2841_323264.html" target="_blank">
#                     <img src="//n.sinaimg.cn/news/1_img/vcg/8de453bf/107/w1024h683/20181002/T4Xg-hkvrhpr9849249.jpg" width="150" height="100" alt="" title="">
#                     <span class="mask">庆祝国庆69周年 香港举行国庆烟花汇演</span>
#                 </a>
#             </li>
#
#         </ul>
#     </div>
#     <a class="btn-box" target="_blank" href="http://slide.news.sina.com.cn/c/">
#         更多
#     </a>
# </div>
# 			<!--seo start-->
# 			<div style="display:none;">
# 	<ul>
# 		<li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289008.shtml">上海国际艺术节江苏文化周节目出炉</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289005.shtml">国庆7天江苏用电同比增长2.7%</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289004.shtml">国庆期间全省安全生产形势平稳</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2288997.shtml">第九届环太湖国际公路自行车赛无锡开幕</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2143733.shtml">前瞻李克强塔吉克斯坦之行：深挖中塔合作 打造上合合作“新增长点”</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ifxeuwws2288977.shtml">中共中央办公厅、国务院办公厅印发《关于加强文物保护利用改革的若干意见》</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ifxeuwws2288915.shtml">陕西通信管理局组织开展国庆节前廉政警示教育</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ifxeuwws2288909.shtml">河南通信管理局党组理论学习中心组专题学习《中国共产党纪律处分条例》</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143290.shtml">助推制造业转型发展 市人大赴嘉定专题调研</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143288.shtml">重点商圈诚信指数出炉 南京西路商圈、徐家汇商圈、淮海中路商圈名列三甲</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143355.shtml">调整到“最佳状态”迎接进博会 青浦配套项目全部完工</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2288891.shtml">将“一江一河”沿岸打造成标杆区域 李强调研黄浦江、苏州河沿岸规划建设情况</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2288890.shtml">新时代上海继续以开放赢得未来 应勇主持市政府常务会议</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143294.shtml">为进口博览会提供司法保障 西虹桥（进博会）法庭揭牌</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143293.shtml">将进博会办成国际一流博览会 首届中国国际进口博览会执委会第一次会议在沪召开</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2288884.shtml">新企业新项目入驻势头旺 奉贤每个工作日诞生二百四十家企业</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2288868.shtml">松江“筑巢引凤” 计划用三到五年推出1万套以租赁为主高品质人才公寓</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2143172.shtml">东部地区高校今秋起实施“慕课西行计划” 华理携手喀大首次试点共修精品课程</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289515.shtml">当着部长的面 澳商界大佬怒斥对华政策“脑残”</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289518.shtml">省经信委党组：启动对下级党组织巡察工作</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2140667.shtml">肇始于范冰冰 税务总局开展影视行业税收自查自纠</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2289305.shtml">株洲：70余万人参与党纪法规知识抢答赛</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2136012.shtml">审计署兰州特派办：强力推进网络和信息安全管理工作</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2133025.shtml">马英九吃喜酒时吐露婚姻秘诀：要让太太完全执政</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2131164.shtml">节后上班多收心 按下工作“快进键”</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286433.shtml">岳阳通报5起领导干部违规插手干预工程建设领域行为典型案件</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2131015.shtml">河北局开展“不忘初心、牢记使命”主题教育活动</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2130988.shtml">广东局召开全系统创建模范机关活动动员部署电视电话会议</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ifxeuwws2286422.shtml">浙江局部署寄递渠道安全管理工作</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2144974.shtml">海口绕城公路美兰国际机场至演丰段公路项目施工图设计获批</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286346.shtml">“四路大军”集结“双创”主战场</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286330.shtml">7市联动 沱江流域建立横向生态保护补偿机制</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286304.shtml">【案例解读监察法】违反监察法且构成犯罪的追究刑事责任</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2129680.shtml">湖北省恩施自治州审计局“三结合”贯彻落实审慎评判实施办法</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ifxeuwws2286128.shtml">安徽省审计厅专题传达学习审计署会议精神</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286232.shtml">青海长江源村：团结奋进谱写幸福生活 ...
#
# 传达学习习近平总书记在深入推进东北振兴座谈会上的重要讲话精神等内容</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286245.shtml">我省网络人士走基层主题考察学习活动启动</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2287201.shtml">武宣法院以党建攻坚“执行难”</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286676.shtml">市政协举行机关处级以上干部会议
#
# 传达学习习近平总书记在深入推进东北振兴座谈会上的重要讲话精神</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2130786.shtml">驻省国资委纪检监察组:开展业务培训 强素质 提能力</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286674.shtml">市委宣传部和市委教科工委召开干部会议</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286516.shtml">我省602种进口药抗癌药降价 还将继续下调一批药品价格</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2130898.shtml">王常松在省纪委常委（扩大）会议传达学习习近平总书记重要讲话和重要指示精神时要求 加强监督检查为推进全面振兴提供纪律保障</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2130927.shtml">张效廉在省委宣传部理论学习中心组集体学习会上强调：牢记嘱托凝心聚力不负使命锐意进取</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2130930.shtml">黑龙江日报评论：沿着总书记指明的方向奋勇前进 二论学习贯彻习近平总书记考察黑龙江和深入推进东北振兴座谈会重要讲话精神</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283600.shtml">南宁举全市之力推进园博园建设</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2116477.shtml">全力以赴统筹推进园博会各项筹办工作</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283598.shtml">园博会开幕倒计时60天暨园博园设备设施调试运行启动，绿城向世界发出邀请</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283593.shtml">市政协召开十一届三十三次主席会议</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283513.shtml">【案例解读监察法】违反监察法且构成犯罪的追究刑事责任</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283506.shtml">牢牢掌握习近平总书记提倡的学习方法</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283498.shtml">“创时代”的四川故事</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283501.shtml">【评论】“庸懒散”者，快告别“昨日之我”</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2283951.shtml">一种风尚崇德向善的力量在巴蜀大地弘扬</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286408.shtml">游客增长超五成旅游收入超六成</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2117566.shtml">英特尔发布第九代酷睿处理器 竞争加剧下的提速|新京报财讯</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286406.shtml">我省安全生产形势总体稳定</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2286243.shtml">我省干部群众认真收看《平“语”近人——习近平总书记用典》特别节目</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2284136.shtml">第22届环球夫人大赛东莞赛区首场比赛盛大开幕 22位夫人大放异彩</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2102112.shtml">户籍小窗口折射民生大变化</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2280778.shtml">前8个月我市重大项目建设有序推进</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2280612.shtml">我省2019年全国硕士研究生招生考试网上报名10月10日开始</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2280605.shtml">50位老乡获评首届“四川脱贫榜样” “四大片区”获奖人数占比76%</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2100863.shtml">国家邮政局局长马军胜2018年世界邮政日致辞</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2281017.shtml">新疆​乌奎高速3车追尾后两车“叠罗汉”</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2281241.shtml">深圳智能制造群像：构建技术壁垒和产业协同的竞争力</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2281239.shtml">“银十”开局遇冷：降准或难改楼市颓势</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2279572.shtml">谷歌人工智能公司去年税前亏损扩大近3亿英镑 员工成本增长91%|新京报财讯</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2097262.shtml">因两宗借款、买卖合同 英威腾董事长所持25%公司股份遭司法冻结|新京报财讯</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2099137.shtml">央媒“官泄”新型轰炸机命名轰-20 研发有大进展</a></li><li><a href="https://news.sina.com.cn/o/2018-10-09/doc-ihkvrhpt2105016.shtml">央媒“官泄”新型战略轰炸机命名轰-20，研发取得重大进展</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2097261.shtml">中弘股份新增逾期债务8519万 申请延期回复因5亿债务纠纷所收关注函 | 新京报财讯</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ifxeuwws2280385.shtml">蓬佩奥访华聚焦朝核但难避中美关系 否认围堵中国</a></li><li><a href="https://news.sina.com.cn/c/2018-10-09/doc-ihkvrhpt2094054.shtml">京山警方通报“9·28”双尸案：嫌犯被抓因琐事争吵杀人|沸点</a></li><l ...
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws1854517.shtml" target="_blank"  title="冯小刚等上演大逃离 “税收洼地”霍尔果斯怎么了">冯小刚等上演大逃离 “税收洼地”霍尔果斯怎么了</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws1854839.shtml" target="_blank"  title="浙江女首富周晓光被列入被执行人名单 卖资产自救">浙江女首富周晓光被列入被执行人名单 卖资产自救</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ihkvrhps9590737.shtml" target="_blank"  title="现任国际刑警组织主席公安部副部长孟宏伟被查">现任国际刑警组织主席公安部副部长孟宏伟被查</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ihkvrhps9870821.shtml" target="_blank"  title="副主任被称“拼命三郎” 却生活奢华家有奔驰奥迪">副主任被称“拼命三郎” 却生活奢华家有奔驰奥迪</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws1843241.shtml" target="_blank"  title="公安部副部长孟宏伟涉嫌违法被查(图/简历)">公安部副部长孟宏伟涉嫌违法被查(图/简历)</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ihkvrhps9700381.shtml" target="_blank"  title="中国建造又添新杰作 一桥飞架打通这国家发展经脉">中国建造又添新杰作 一桥飞架打通这国家发展经脉</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ihkvrhps9767479.shtml" target="_blank"  title="美国务卿蓬佩奥今访华 专家解读三大看点">美国务卿蓬佩奥今访华 专家解读三大看点</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws2030340.shtml" target="_blank"  title="王毅会见蓬佩奥：要求美方立即停止错误言行">王毅会见蓬佩奥：要求美方立即停止错误言行</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws1867124.shtml" target="_blank"  title="国际组织发“寻人启事”找的副部 刚刚落马了">国际组织发“寻人启事”找的副部 刚刚落马了</a>
# 			</li>			<li>
# 				<a href="https://news.sina.com.cn/o/2018-10-08/doc-ifxeuwws2072120.shtml" target="_blank"  title="范冰冰偷逃税案件中有关责任单位和责任人被问责">范冰冰偷逃税案件中有关责任单位和责任人被问责</a>
# 			</li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-07/doc-ihkvrhps9506414.shtml" target="_blank"  title="崔永元举报“阴阳合同”获奖10万 华谊兄弟再表态">崔永元举报“阴阳合同”获奖10万 华谊兄弟再表态</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-07/doc-ihkvrhps8481818.shtml" target="_blank"  title="回应美副总统“檄文”演说 台湾主持人为大陆出手">回应美副总统“檄文”演说 台湾主持人为大陆出手</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/zj/2018-10-07/doc-ihkvrhps9403731.shtml" target="_blank"  title="多地因楼盘降价引发纠纷 楼市几大信号不可不重视">多地因楼盘降价引发纠纷 楼市几大信号不可不重视</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-08/doc-ifxeuwws1854517.shtml" target="_blank"  title="冯小刚等上演大逃离 “税收洼地”霍尔果斯怎么了">冯小刚等上演大逃离 “税收洼地”霍尔果斯怎么了</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/zj/2018-10-07/doc-ifxeuwws1817992.shtml" target="_blank"  title="媒体:为啥日实体店干掉电商 中国电商干掉实体店?">媒体:为啥日实体店干掉电商 中国电商干掉实体店?</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-06/doc-ihkvrhps6250565.shtml" target="_blank"  title="河北辅警追捕辽宁越狱犯时出车祸 2人殉职2人受伤">河北辅警追捕辽宁越狱犯时出车祸 2人殉职2人受伤</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/o/2018-10-08/doc-ifxeuwws2072120.shtml" target="_blank"  title="范冰冰偷逃税案件中有关责任单位和责任人被问责">范冰冰偷逃税案件中有关责任单位和责任人被问责</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-08/doc-ihkvrhpt0527621.shtml" target="_blank"  title="昨夜范冰冰悄悄发了条微博  网友：她在试探">昨夜范冰冰悄悄发了条微博  网友：她在试探</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/c/2018-10-05/doc-ihkvrhps4852472.shtml" target="_blank"  title="红网:范冰冰客串片酬3000万逃税700多万 贪得无厌">红网:范冰冰客串片酬3000万逃税700多万 贪得无厌</a>
#             </li>            <li>
#                 <a href="https://news.sina.com.cn/w/2018-10-06/doc-ihkvrhps6647004.shtml" target="_blank"  title="北美自贸协议夹带“防华”条款 英媒：欲孤立中国">北美自贸协议夹带“防华”条款 英媒：欲孤立中国</a>
#             </li>	</ul>
# </div>
# 			<!--seo end-->
#             <div class="js-feed-cont" id="feed_cont"></div>
#         </div>
#         <div class="right-content-1">
#             <div class="news-rank">
#     <div class="tlt"  data-sudaclick="ranklist_news_p">
#         <em><a href="http://news.sina.com.cn/hotnews/" target="_blank">新闻排行</a></em>
#     </div>
#     <div class="news-rank-content">
#
#         <div class="news-rank-conb1">
#             <div class="news-tlt">
#                 <a href="javascript:void(0);"  data-sudaclick="rankliranklist_news_today_click_i" target="_blank" class="news-tlt-nav current"><i class="angle"></i>点击排行</a>
#                 <a href="javascript:void(0);"  data-sudaclick="ranklist_news_today_comment_i" target="_blank" class="news-tlt-nav"><i class="angle"></i>评论排行</a>
# 				<span class="slash"></span>
#             </div>
#             <ul class="hot-news-ul" data-sudaclick="ranklist_today_comment_items_p">
#
#             </ul>
#             <ul class="hot-news-ul hiden" data-sudaclick="ranklist_news_comment_hotitems_p">
#
#             </ul>
#         </div>
#
#     </div>
# </div>
#
#
#
#             <!-- 底部导航 start -->
# <div class="footer_box">
#     <div class="view-module">
#         <span class="view-phone marginTop24"><a href="http://news.sina.com.cn/feedback/post.html" target="_blank"><i class="icon-pen"></i>新浪新闻意见反馈留言板 </a></span>
#         <span class="view-phone"><i class="icon-phone"></i>400-690-0000  欢迎批评指正</span>
#     </div>
#     <div class="nav-link-box" data-sudaclick="footer_p">
#         <ul>
#             <li>
#                 <a href="http://corp.sina.com.cn/chn/sina_index.html" target="_blank">新浪简介</a>
#                 <span>|</span>
#                 <a href="http://emarketing.sina.com.cn/" target="_blank">广告服务</a>
#                 <span>|</span>
#                 <a href="http://corp.sina.com.cn/eng/sina_index_eng.htm" target="_blank">About Sina</a>
#             </li>
#             <li>
#                 <a href="http://www.sina.com.cn/contactus.html" target="_blank">联系我们</a>
#                 <span>|</span>
#                 <a href="http://career.sina.com.cn/" target="_blank">招聘信息</a>
#                 <span>|</span>
#                 <a href="http://login.sina.com.cn/signup/signup" target="_blank">通行证注册</a>
#             </li>
#             <li>
#                 <a href="http://help.sina.com.cn/" target="_blank">产品答疑</a>
#                 <span>|</span>
#                 <a href="http://corp.sina.com.cn/lawfirm/sina.htm" target="_blank">网站律师</a>
#                 <span>|</span>
#                 <a href="http://english.sina.com/" target="_blank">SINA English</a>
#             </li>
#         </ul>
#
#     </div>
#     <div class="report-infor">
#         <p>违法和不良信息举报电话：010-62675637<br/>
#         举报邮箱：jubao@vip.sina.com</p>
#     </div>
#     <div class="copy-right">
#         <p>Copyright © 1996-2018 SINA Corporation</p>
#         <p>All Rights Reserved  新浪公司 <a href="https://corp.sina.com.cn/chn/copyright.html" target="_blank">版权所有</a> </p>
#     </div>
# </div>
#         </div>
#     </div>
#     <!-- 正文页浮层 -->
# <div class="page-right-bar">
#     <span class="fbr-box fbr-down">
#         <span class="fbr-pic" id="weixinPic">
#             <img src="//n2.sinaimg.cn/ent/home1704/images/pages/fbr-ewm.png" width="65" height="65" data-echo="//n2.sinaimg.cn/ent/home1704/images/pages/fbr-ewm.png" alt="">
#
#             <img src="//n.sinaimg.cn/tech/index_v17/xinwen_fix.png" class="weixin_big">
#
#             <span class="fbr-title" id="weixinTitle">下载<i>新浪新闻</i></span>
#         </span>
#
#     </span>
#     <a class="right-bar-btn fbr-pic" id="weixinText" href="javascript:void(0);" data-sudaclick="float_newsapp_i">
#         新浪新闻App
#     </a>
#     <img src="//n.sinaimg.cn/tech/index_v17/xinwen_fix.png" class="weixin_big1">
#     <!-- <a href="javascript" data-sudaclick="float_home_p" node-type="toHome" class='right-bar-btn btn-home'>>新浪新闻客户端</a> -->
#     <a href="http://news.sina.com.cn/feedback/post.html" target="_blank" data-sudaclick="float_feedback_p" class="right-bar-btn">
#         <div class=" btn-survey"></div>
#         <p>意见反馈</p>
#     </a>
#    <a data-sudaclick="float_survey_p" node-type="sittingA" class="right-bar-btn sittingA"></a>
#     <a href="javascript:;" data-sudaclick="float_top_i" node-type="toTop" class='right-bar-btn fadeOut'>
#         <div class="btn-toTop"></div>
#         <p>返回顶部</p>
#     </a>
# </div>
#     <!--对联广告 20150909 15:10:00 leitao Start-->
#     <ins class="sinaads" data-ad-pdps="PDPS000000058097" data-ad-type="float"></ins>
#     <script>(sinaads = window.sinaads || []).push({
#         params : {
#             sinaads_float_show_pos: 800,
#             sinaads_float_top : 46
#         }
#     });
#     </script>
#     <!--对联广告 20150909 15:10:00 leitao End-->
#     <!-- start dmp -->
#     <script type="text/javascript">
#     (function(d, s, id) {
#     var n = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     s = d.createElement(s);
#     s.id = id;
#     s.setAttribute('charset', 'utf-8');
#     s.src = '//d' + Math.floor(0 + Math.random() * (8 - 0 + 1)) + '.sina.com.cn/litong/zhitou/sinaads/src/spec/sinaads_ck.js';
#     n.parentNode.insertBefore(s, n);
#     })(document, 'script', 'sinaads-ck-script');
#     </script>
#     <!-- end dmp -->
#     <script type="text/javascript" src="//tech.sina.com.cn/js/717/20140827/index2014/top.js" charset="gb2312"></script>
#     <script language='javascript' charset='utf-8' src='//i.sso.sina.com.cn/js/ssologin.js'></script>
#     <script type="text/javascript" src="//i.sso.sina.com.cn/js/outlogin_layer.js" charset="utf-8"></script>
#     <script type="text/javascript" src="//i.sso.sina.com.cn/js/user_panel_new_version_v2.js" charset="utf-8"></script>
#     <script type="text/javascript" src="//ent.sina.com.cn/470/2014/0328/search_suggest.js"></script>
#     <script charset="utf-8" type="text/javascript" src="//n.sinaimg.cn/common/channelnav/js/nav.js"></script>
#     <!-- FEED start -->
#
#     <!--feed流配置-->
#        <script type="text/javascript">
#         var FEED_CARD_INFO = {
#             containerID: 'feed_cont', // 容器ID
#             containerWidth: 672, // 默认宽度是660
#             loadType: 1, // 加载类型 1表示点击更多加载, 2表示自动加载
#             autoLoadDistance: '', // 如果是自动加载, 有时候feed流并没有放在最下面, 所以scrollEnd的时候要判断这个距离
#             clickLoadText: '点击加载更多',
#             summaryKey: 'summary', // 摘要使用字段
#             supportNotification: true,// 最左边的列表是否添加提醒功能
#             notificationTemplate: '有{n}条消息，点击查看',// 提醒的格式
#             notificationTimeout: 1000 * 30,// 提醒的事件间隔
#             pageSize: 20, // 每次加载条数
#             stepSize: 1, // 加载三次之后出分页
#             moreTagTemplate: '点击查看更多关于“{n}”的文章',
#
#             /*
#              * 评论相关配置
#              */
#             // 1. 是否支持当前页展开评论
#             enablePageComment: false,
#             // 2. 评论组件编码,默认是gbk
#             pageCommentEncoding: 'gbk',
#             // 3. 是否显示盖楼,默认0,还可以为1
#             pageCommentShowReply: 0,
#             // 4. 评论显示字数
#             pageCommentMaxWordCount: 110,
#             // 5. 最热评论默认显示条数
#             pageCommentHotPageNum: 3,
#             // 6. 最新评论默认显示条数
#             pageCommentFirstPageNum: 10,
#
#             pageid: 121, // pageid与lid共同定位一个api地址
#             homeid: 30003, // 用来上传定制信息, 见邮件[feed流订阅homeid分配]
#
#             supportTabEdit: false, //是否支持兴趣设置
#             editTips: ['温馨提示：点击下一步，调整分类顺序。（至少选择一个分类）', '温馨提示：完成设置后，将会根据兴趣推荐全新内容~'],
#             toFilterNews: [], // 过滤从feed系统走，此处可置空
#             isTabFixed: false,
#             fixedTop: 0,
#             supportKeywords: false, // 是否支持热词定制
#             hotNewsCount: 200, //评论超过该数字显示热icon
#             enableTagFeed: false,// 是否支持点击关键词加载列表，默认是false
#             tagURL: 'http://tags.finance.sina.com.cn',
#             yPosition: 'auto', // 如果不固定，则给一个auto，自动计算
#             tabHeight: 50,
#             noDataText: '没有相关新闻',
#             //最左边固定tab
#             firstTab: {
#                 txt: '最新新闻',
#                 lid: 1356
#             },
#
#             // 默认tab
#             tabs: [-4000],
#             allTabs: [-4000],
#             tabInfos: {
# /*
#                 'tab_-4000': {
#                     txt: '理财自媒体',
#                     lid: -4000,
#                     //url: 'http://feed.mix.sina.com.cn/api/roll/get?pageid=155&lid=1686&num=10&page=1'
#                     //url: 'http://feed.mix.sina.com.cn/api/zt/get?sid_1_value=2016qglh&sid_2_value=3&channelid=1&len=5'
#                     url: 'http://cj.sina.com.cn/api/article/feed_author?num=10&page=1'
#                 }
# */
#             },
#             requireLogin: function(){
#               var UserPanel = SINA_USER_PANEL;
#               UserPanel.setOutLoginMiddle();
#               UserPanel.getOutLogin().show();
#               // 可添加提示
#               __SinaTopBar__.user.showTip('<span>温馨提示: </span>您已经完成兴趣设置，建议登录后保存。');
#             },
#             isLogin: function(){
#               if(window.SINA_OUTLOGIN_LAYER){
#                 return window.SINA_OUTLOGIN_LAYER.isLogin();
#               }
#               return false;
#             }
#         };
#     </script>
#     <script type="text/javascript" charset="gb2312" src="//tech.sina.com.cn/js/717/20141112/index2014/doT.min.js"></script>
#     <script type="text/javascript" charset="gb2312" src="//news.sina.com.cn/blank/tianyi/feed-news.js"></script>
#     <!--/feed流配置-->
# 	<script type="text/javascript" src="//n.sinaimg.cn/news/643213b9/20180725/suda_log_1459340870608.js"></script>
#     <script type="text/javascript" src="//www.sinaimg.cn/unipro/pub/suda_m_v634.js"></script>
#     <script type="text/javascript">suds_init(979,100.0000,1515,2)</script>
# <script type="text/javascript" src="//simg.sinajs.cn/products/news_finance/2018/pc_china_home/js/vender-5b1f99.js"></script><script type="text/javascript" src="//simg.sinajs.cn/products/news_finance/2018/pc_china_home/js/index-2b1eed.js"></script><!-- body code begin -->
# <script type="text/javascript">
# (function(){
#     if(window.top !== window.self || window._thereIsNoRealTimeMessage){return};
#     var script = document.createElement('script');
#     script.setAttribute('charset', 'gb2312');
#     script.src = '//news.sina.com.cn/js/694/2012/0830/realtime.js?ver=1.5.1';
#     document.getElementsByTagName('head')[0].appendChild(script);
# })();
# </script>
#
# <!-- SSO_UPDATECOOKIE_START -->
# <script type="text/javascript">var sinaSSOManager=sinaSSOManager||{};sinaSSOManager.q=function(b){if(typeof b!="object"){return""}var a=new Array();for(key in b){a.push(key+"="+encodeURIComponent(b[key]))}return a.join("&")};sinaSSOManager.es=function(f,d,e){var c=document.getElementsByTagName("head")[0];var a=document.getElementById(f);if(a){c.removeChild(a)}var b=document.createElement("script");if(e){b.charset=e}else{b.charset="gb2312"}b.id=f;b.type="text/javascript";d+=(/\?/.test(d)?"&":"?")+"_="+(new Date()).getTime();b.src=d;c.appendChild(b)};sinaSSOManager.doCrossDomainCallBack=function(a){sinaSSOManager.crossDomainCounter++;document.getElementsByTagName("head")[0].removeChild(document.getElementById(a.scriptId))};sinaSSOManager.crossDomainCallBack=function(a){if(!a||a.retcode!=0){return false}var d=a.arrURL;var b,f;var e={callback:"sinaSSOManager.doCrossDomainCallBack"};sinaSSOManager.crossDomainCounter=0;if(d.length==0){return true}for(var c=0;c<d.length;c++){b=d[c];f="ssoscript"+c;e.scriptId=f;b=b+(/\?/.test(b)?"&":"?")+sinaSSOManager.q(e);sinaSSOManager.es(f,b)}};sinaSSOManager.updateCookieCallBack=function(c){var d="ssoCrossDomainScriptId";var a="http://login.sina.com.cn/sso/crossdomain.php";if(c.retcode==0){var e={scriptId:d,callback:"sinaSSOManager.crossDomainCallBack",action:"login",domain:"sina.com.cn"};var b=a+"?"+sinaSSOManager.q(e);sinaSSOManager.es(d,b)}else{}};sinaSSOManager.updateCookie=function(){var g=1800;var p=7200;var b="ssoLoginScript";var h=3600*24;var i="sina.com.cn";var m=1800;var l="http://login.sina.com.cn/sso/updatetgt.php";var n=null;var f=function(e){var r=null;var q=null;switch(e){case"sina.com.cn":q=sinaSSOManager.getSinaCookie();if(q){r=q.et}break;case"sina.cn":q=sinaSSOManager.getSinaCookie();if(q){r=q.et}break;case"51uc.com":q=sinaSSOManager.getSinaCookie();if(q){r=q.et}break}return r};var j=function(){try{return f(i)}catch(e){return null}};try{if(g>5){if(n!=null){clearTimeout(n)}n=setTimeout("sinaSSOManager.updateCookie()",g*1000)}var d=j();var c=(new Date()).getTime()/1000;var o={};if(d==null){o={retcode:6102}}else{if(d<c){o={retcode:6203}}else{if(d-h+m>c){o={retcode:6110}}else{if(d-c>p){o={retcode:6111}}}}}if(o.retcode!==undefined){return false}var a=l+"?callback=sinaSSOManager.updateCookieCallBack";sinaSSOManager.es(b,a)}catch(k){}return true};sinaSSOManager.updateCookie();</script>
# <!-- SSO_UPDATECOOKIE_END -->
#
# <!-- start dmp -->
# <script type="text/javascript">
# (function(d, s, id) {
# var n = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# s = d.createElement(s);
# s.id = id;
# s.setAttribute('charset', 'utf-8');
# s.src = '//d' + Math.floor(0 + Math.random() * (8 - 0 + 1)) + '.sina.com.cn/litong/zhitou/sinaads/src/spec/sinaads_ck.js';
# n.parentNode.insertBefore(s, n);
# })(document, 'script', 'sinaads-ck-script');
# </script>
# <!-- end dmp -->
#
# <!-- body code end -->
#
# </body>
#
# </html>

# %%
print(type(res))
# Out:
# <class 'requests.models.Response'>

# %%
from bs4 import BeautifulSoup
html_sample = '\
<html> \
    <body> \
    <h1 id = "title">Hello Bird</h1> \
    <a href = "#" class ="link">This is a link</a> \
    <a href = "# link2" class = "link">This is link2</a> \
    </body> \
    </html>'
soup = BeautifulSoup(html_sample, 'html.parser')
print(soup.text)
# Out:
#   Hello Bird This is a link This is link2

# %%
from bs4 import BeautifulSoup
html_sample = '''<html> 
    <body> 
    <h1 id = "title">Hello Bird</h1> 
    <a href = "#" class ="link">This is a link</a> 
    <a href = "# link2" class = 'link'>This is link2</a> 
    </body> 
    </html>'''
soup = BeautifulSoup(html_sample, 'html.parser')
print(type(soup))
print(soup.text)
# Out:
# <class 'bs4.BeautifulSoup'>
#
#
# Hello Bird
# This is a link
# This is link2
